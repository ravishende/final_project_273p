# %%
from datasets import load_dataset
import kagglehub

imgs_by_llm = load_dataset("Rajarshi-Roy-research/Defactify_Image_Dataset")
path_ai_vs_real = kagglehub.dataset_download("birdy654/cifake-real-and-ai-generated-synthetic-images")
